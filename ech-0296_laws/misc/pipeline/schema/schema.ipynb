# %% [markdown]
# # schema-pipeline
#
# The ELI↔AKN crosswalk: SSSOM mappings, generated SKOS concept schemes, LinkML-derived cardinality/range
# docs (matching the upstream eCH group's own `gen-doc` convention). Imports `pipeline/schema/meta`
# (`schema.yaml`+`schema_common.yml`, vendored from `ech-0292_meta`/`ch.paf.link`) for FRBR classes and the
# shared mixins (`HasTemporalValidity`, etc.). See `PIPELINE.md`/`DECISIONS.md` for background.
#
# Reference material alongside this notebook: `fedlex-sparql/` (live SPARQL queries against jolux/Fedlex
# LINDAS data), `ontology-tutorial.md` (LinkML's own ontology-mapping pattern), `linkml-tutorial/`.

# %% [markdown]
# ## 1. Load sources
#
# ELI ontology (once the authoritative Excel sheet arrives — see `TODO.md` priority item), the AKN-NC
# in-scope elements/attributes, `pipeline/schema/meta`'s FRBR classes.

# %%
# TODO: load ELI ontology (from the Excel sheet, once provided), AKN-NC subset, meta/schema.yaml

# %% [markdown]
# ## 2. Validate the SSSOM TSV + local SKOS schemes

# %%
# TODO: sssom validate mappings/eli-akn.sssom.tsv

# %% [markdown]
# ## 3. Generate local concept schemes (SKOS)

# %%
# TODO: LinkML enum/CSV -> SKOS TTL/JSON-LD

# %% [markdown]
# ## 4. Living tables (crosswalk coverage, vocabulary coverage)

# %%
# TODO: pandas-built coverage tables

# %% [markdown]
# ## 5. Export
#
# Writes generated vocab/mappings straight into `public/vocab/`, `public/mappings/` and the
# `spec/input/appendix/eli-akn-mapping.md` annex.

# %%
# TODO: export to public/ and spec/input/appendix/eli-akn-mapping.md
